# %% [markdown]
# # パッケージのインストール

# %%
# パッケージのimport
import os
import numpy as np
import pandas as pd
import datetime as dt
#import pandas_profiling as pdp


# 可視化
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
from IPython.display import display
#from paylab import rcParms
# %matplotlib inline
sns.set_style('darkgrid')

# 必要なライブラリを読み込む
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 必要な関数を読み込む
from sklearn.model_selection import train_test_split # 訓練データと検証データに分ける関数
from sklearn.metrics import confusion_matrix, accuracy_score # 混同行列, 予測正解率を求める関数

# Jupyter 上で図を表示するためのコマンド
# %matplotlib inline

# seabornのデフォルトパラメータに設定するコマンド
sns.set()

# 正規化のためのクラス
from sklearn.preprocessing import StandardScaler

# %%
import matplotlib.font_manager
print([f.name for f in matplotlib.font_manager.fontManager.ttflist])
# Out:
# ['DejaVu Sans Mono', 'STIXNonUnicode', 'DejaVu Sans', 'DejaVu Serif', 'STIXSizeTwoSym', 'cmmi10', 'STIXNonUnicode', 'DejaVu Sans Mono', 'STIXSizeTwoSym', 'DejaVu Sans', 'cmb10', 'DejaVu Serif', 'cmex10', 'DejaVu Sans Mono', 'DejaVu Sans Mono', 'cmr10', 'STIXSizeOneSym', 'STIXSizeFiveSym', 'DejaVu Sans Display', 'DejaVu Serif Display', 'STIXNonUnicode', 'DejaVu Sans', 'STIXGeneral', 'cmss10', 'STIXSizeFourSym', 'DejaVu Serif', 'DejaVu Sans', 'cmsy10', 'STIXGeneral', 'STIXSizeThreeSym', 'STIXGeneral', 'STIXSizeFourSym', 'STIXSizeOneSym', 'STIXNonUnicode', 'cmtt10', 'STIXSizeThreeSym', 'DejaVu Serif', 'STIXGeneral', 'Franklin Gothic Demi', 'Magneto', 'Book Antiqua', 'Segoe UI', 'MV Boli', 'Verdana', 'Eras Demi ITC', 'Consolas', 'Gadugi', 'Dubai', 'Jokerman', 'Arial', 'Arial', 'Trebuchet MS', 'Parchment', 'Calisto MT', 'Yu Mincho', 'Constantia', 'Cambria', 'Franklin Gothic Medium Cond', 'Bodoni MT', 'Gill Sans MT', 'Century Schoolbook', 'Gigi', 'Bradley Hand ITC', 'Magneto', 'Dubai', 'OC
# ...

# %%
fonts = mpl.font_manager.findSystemFonts()
sorted([font.split('/')[-1] for font in fonts]) # フォント名だけを切り出し
# Out:
# ['C:\\WINDOWS\\Fonts\\AGENCYB.TTF',
#  'C:\\WINDOWS\\Fonts\\AGENCYR.TTF',
#  'C:\\WINDOWS\\Fonts\\ALGER.TTF',
#  'C:\\WINDOWS\\Fonts\\ANTQUAB.TTF',
#  'C:\\WINDOWS\\Fonts\\ANTQUABI.TTF',
#  'C:\\WINDOWS\\Fonts\\ANTQUAI.TTF',
#  'C:\\WINDOWS\\Fonts\\ARIALN.TTF',
#  'C:\\WINDOWS\\Fonts\\ARIALNB.TTF',
#  'C:\\WINDOWS\\Fonts\\ARIALNBI.TTF',
#  'C:\\WINDOWS\\Fonts\\ARIALNI.TTF',
#  'C:\\WINDOWS\\Fonts\\ARLRDBD.TTF',
#  'C:\\WINDOWS\\Fonts\\BASKVILL.TTF',
#  'C:\\WINDOWS\\Fonts\\BAUHS93.TTF',
#  'C:\\WINDOWS\\Fonts\\BELL.TTF',
#  'C:\\WINDOWS\\Fonts\\BELLB.TTF',
#  'C:\\WINDOWS\\Fonts\\BELLI.TTF',
#  'C:\\WINDOWS\\Fonts\\BERNHC.TTF',
#  'C:\\WINDOWS\\Fonts\\BKANT.TTF',
#  'C:\\WINDOWS\\Fonts\\BOD_B.TTF',
#  'C:\\WINDOWS\\Fonts\\BOD_BI.TTF',
#  'C:\\WINDOWS\\Fonts\\BOD_BLAI.TTF',
#  'C:\\WINDOWS\\Fonts\\BOD_BLAR.TTF',
#  'C:\\WINDOWS\\Fonts\\BOD_CB.TTF',
#  'C:\\WINDOWS\\Fonts\\BOD_CBI.TTF',
#  'C:\\WINDOWS\\Fonts\\BOD_CI.TTF',
#  'C:\\WINDOWS\\Fonts\\BOD_CR.TTF',
# ...

# %%
# 日本語対応フォントに変える
# （環境によって異なります。notebook内のみで有効な変更）
# mpl.rcParams['font.family'] =  'MigMix 2P'
mpl.rcParams['font.family'] =  'HGMaruGothicMPRO'

# windows10環境の場合は、IPAフォントをダウンロードした方がよい
# https://qiita.com/yniji/items/3fac25c2ffa316990d0c
# http://akiyoko.hatenablog.jp/entry/2017/04/11/080446

# フォントサイズも大きめにしておく
mpl.rcParams['font.size'] = 12

# %%
print(mpl.matplotlib_fname())
# Out:
# C:\Users\tetsunari_tsuji\Anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %% [markdown]
# # データの取り込み

# %% [markdown]
# FIFA 2018 Statistics.csv

# %%
FIFA = pd.read_csv('FIFA 2018 Statistics.csv', encoding = "utf-8")

# %%
FIFA = pd.DataFrame(FIFA)

# %%
FIFA_B = FIFA[FIFA['Team'].isin(['Spain' , 'Portugal' , 'Morocco' , 'Iran'])]

# %%
FIFA_B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14 entries, 4 to 100
# Data columns (total 27 columns):
# Date                      14 non-null object
# Team                      14 non-null object
# Opponent                  14 non-null object
# Goal Scored               14 non-null int64
# Ball Possession %         14 non-null int64
# Attempts                  14 non-null int64
# On-Target                 14 non-null int64
# Off-Target                14 non-null int64
# Blocked                   14 non-null int64
# Corners                   14 non-null int64
# Offsides                  14 non-null int64
# Free Kicks                14 non-null int64
# Saves                     14 non-null int64
# Pass Accuracy %           14 non-null int64
# Passes                    14 non-null int64
# Distance Covered (Kms)    14 non-null int64
# Fouls Committed           14 non-null int64
# Yellow Card               14 non-null int64
# Yellow & Red              14 non-null int64
# ...

# %%
fifa_b = FIFA_B

# %%
fifa_b = fifa_b[:12]

# %%
fifa_b_team = fifa_b.groupby('Team').sum()

# %%
fifa_b_team['Attempts'].sort_values()
# Out:
# Team
# Iran        21
# Portugal    32
# Morocco     35
# Spain       45
# Name: Attempts, dtype: int64
